# %% [markdown]
# # My First Data Analysis
# This is my first Jupyter notebook in GitHub!

# %%
# Hello GitHub!
print('Hello, GitHub!')

# %%
import pandas as pd

# Sample data
data = {'month': ['Jan', 'Feb', 'Mar', 'Apr'],
        'sales': [1000, 1200, 950, 1400]}
df = pd.DataFrame(data)
print(df)
